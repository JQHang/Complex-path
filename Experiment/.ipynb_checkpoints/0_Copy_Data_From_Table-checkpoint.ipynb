# %%
# ! /usr/bin/env python
# -*- coding: utf-8 -*-

from __future__ import division
import pandas as pd
from collections import defaultdict
import math
import os
import io
import time
import copy
import re
import gc
import json
import sys
sys.path.append("..")

import random
from random import sample
import numpy as np
import pandas as pd

from tqdm import tqdm

from datetime import date, datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
import re
import xlrd
import warnings
import matplotlib.ticker as mtick
from matplotlib.font_manager import FontProperties
# %matplotlib inline

# spark相关配置
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.types import *
from pyspark import StorageLevel
from pyspark.sql import HiveContext,SparkSession
from pyspark.sql.window import Window
from pyspark.sql.functions import col, row_number

from pyspark.ml.feature import StandardScaler
from pyspark.ml.feature import MinMaxScaler
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Pipeline
from pyspark.sql import Row
from pyspark.sql.functions import udf
from pyspark.sql.types import DoubleType

# %%
#显示所有列
pd.set_option('display.max_columns', None)

#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

# %%
# 创建spark_session
os.environ['PYSPARK_PYTHON']="/usr/local/anaconda3/bin/python"

def Start_Spark():
    Spark_Session = SparkSession.builder \
                    .appName("kg_spark_for_model") \
                    .enableHiveSupport() \
                    .config("spark.default.parallelism", "600") \
                    .config("spark.sql.shuffle.partitions", "3000") \
                    .config("spark.sql.broadcastTimeout","3600")\
                    .config("spark.driver.memory", "200g") \
                    .config("spark.executor.memory", "40g")\
                    .config("spark.yarn.appMasterEnv.yarn.nodemanager.container-executor.class", "DockerLinuxContainer")\
                    .config("spark.executorEnv.yarn.nodemanager.container-executor.class", "DockerLinuxContainer")\
                    .config("spark.yarn.appMasterEnv.yarn.nodemanager.docker-container-executor.image-name", 
                            "bdp-docker.jd.com:5000/wise_mart_bag:latest")\
                    .config("spark.executorEnv.yarn.nodemanager.docker-container-executor.image-name", 
                            "bdp-docker.jd.com:5000/wise_mart_bag:latest")\
                    .config("spark.sql.crossJoin.enabled", "true")\
                    .config("spark.driver.maxResultSize", "40g")\
                    .config("spark.sql.autoBroadcastJoinThreshold","-1")\
                    .getOrCreate()

    return Spark_Session

# %%
# 固定随机值
def setup_seed(seed):
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    
setup_seed(42)

# %%
Spark_Session = Start_Spark()

# %%
# 目标时间
# Aim_Feature_Table_Time_List = ['2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01']
# Aim_Feature_Table_Time_List = ['2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01']
Aim_Feature_Table_Time_List = ['2023-05-01']

# Source_Table_Name = "tmp.tmp___JL_MP_N_Feat___mobile_send_from_site___Road_Node_UID___Groupby_Result___04_18"
# Target_Table_Name = "tmp.tmp___JingLian_Meta_Path_Feature___mobile_send_from_site___Road_Node_UID___Groupby_Result___04_18"

# Source_Table_Name_list = ["tmp.tmp___JL_MP_N_Feat___mobile_send_from_site___Road_Node_UID___Groupby_Summary___04_18",
#                           "tmp.tmp___JL_MP_N_Feat___mobile_send_from_site___Site_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JL_MP_N_Feat___mobile_send_from_site___Site_Node_UID___Groupby_Summary___04_18"]

# Target_Table_Name_list = ["tmp.tmp___JingLian_Meta_Path_Feature___mobile_send_from_site___Road_Node_UID___Groupby_Result_Summary___04_18",
#                           "tmp.tmp___JingLian_Meta_Path_Feature___mobile_send_from_site___Site_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JingLian_Meta_Path_Feature___mobile_send_from_site___Site_Node_UID___Groupby_Result_Summary___04_18"]

# Source_Table_Name_list = ["tmp.tmp___JL_MP_N_Feat___mobile_receive_from_site___Road_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JL_MP_N_Feat___mobile_receive_from_site___Road_Node_UID___Groupby_Summary___04_18",
#                           "tmp.tmp___JL_MP_N_Feat___mobile_receive_from_site___Site_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JL_MP_N_Feat___mobile_receive_from_site___Site_Node_UID___Groupby_Summary___04_18"]

# Target_Table_Name_list = ["tmp.tmp___JingLian_Meta_Path_Feature___mobile_receive_from_site___Road_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JingLian_Meta_Path_Feature___mobile_receive_from_site___Road_Node_UID___Groupby_Result_Summary___04_18",
#                           "tmp.tmp___JingLian_Meta_Path_Feature___mobile_receive_from_site___Site_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JingLian_Meta_Path_Feature___mobile_receive_from_site___Site_Node_UID___Groupby_Result_Summary___04_18"]

# Source_Table_Name_list = ["tmp.tmp___JL_MP_N_Feat___mobile_company_site___Road_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JL_MP_N_Feat___mobile_company_site___Road_Node_UID___Groupby_Summary___04_18",
#                           "tmp.tmp___JL_MP_N_Feat___mobile_company_site___Site_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JL_MP_N_Feat___mobile_company_site___Site_Node_UID___Groupby_Summary___04_18"]

# Target_Table_Name_list = ["tmp.tmp___JingLian_Meta_Path_Feature___mobile_company_site___Road_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JingLian_Meta_Path_Feature___mobile_company_site___Road_Node_UID___Groupby_Result_Summary___04_18",
#                           "tmp.tmp___JingLian_Meta_Path_Feature___mobile_company_site___Site_Node_UID___Groupby_Result___04_18",
#                           "tmp.tmp___JingLian_Meta_Path_Feature___mobile_company_site___Site_Node_UID___Groupby_Result_Summary___04_18"]

Source_Table_Name_list = ["tmp.tmp___JL_MP_N_Feat___mobile_company_site___Company_Node_UID___Groupby_Result___04_18",
                          "tmp.tmp___JL_MP_N_Feat___mobile_company_site___Company_Node_UID___Groupby_Summary___04_18",
                          "tmp.tmp___JL_MP_N_Feat___company_related_to_industry___Industry_Type_Node_l4_UID___Groupby_Result___04_18",
                          "tmp.tmp___JL_MP_N_Feat___company_related_to_industry___Industry_Type_Node_l4_UID___Groupby_Summary___04_18",
                          "tmp.tmp___JL_MP_N_Feat___company_related_to_industry___Industry_Type_Node_l3_UID___Groupby_Result___04_18",
                          "tmp.tmp___JL_MP_N_Feat___company_related_to_industry___Industry_Type_Node_l3_UID___Groupby_Summary___04_18"]

Target_Table_Name_list = ["tmp.tmp___JingLian_Meta_Path_Feature___mobile_company_site___Company_Node_UID___Groupby_Result___04_18",
                          "tmp.tmp___JingLian_Meta_Path_Feature___mobile_company_site___Company_Node_UID___Groupby_Result_Summary___04_18",
                          "tmp.tmp___JingLian_Meta_Path_Feature___company_related_to_industry___Industry_Type_Node_l4_UID___Groupby_Result___04_18",
                          "tmp.tmp___JingLian_Meta_Path_Feature___company_related_to_industry___Industry_Type_Node_l4_UID___Groupby_Result_Summary___04_18",
                          "tmp.tmp___JingLian_Meta_Path_Feature___company_related_to_industry___Industry_Type_Node_l3_UID___Groupby_Result___04_18",
                          "tmp.tmp___JingLian_Meta_Path_Feature___company_related_to_industry___Industry_Type_Node_l3_UID___Groupby_Result_Summary___04_18"]

# %%
for tmp_table_i in range(len(Source_Table_Name_list)):
    Source_Table_Name = Source_Table_Name_list[tmp_table_i]
    Target_Table_Name = Target_Table_Name_list[tmp_table_i]
    
    print(Source_Table_Name)
    print(Target_Table_Name)
    
    # Read Aim Columns From Target Table
    tmp_sql = "SELECT * FROM " + Target_Table_Name + " LIMIT 5"

    tmp_target_table_rdd = Spark_Session.sql(tmp_sql)

    tmp_target_table_rdd_json = json.loads(tmp_target_table_rdd.schema.json())['fields']

    tmp_target_table_rdd_columns_list = [tmp_col_info['name'] for tmp_col_info in tmp_target_table_rdd_json]

    tmp_target_table_rdd_columns_list.remove('dt')

    for tmp_up_load_table_dt in Aim_Feature_Table_Time_List:
        print(tmp_up_load_table_dt)

        # Read Source Data
        tmp_sql = "SELECT * FROM " + Source_Table_Name

        tmp_source_table_rdd = Spark_Session.sql(tmp_sql)

        # 修正列名
        if 'AVG_clue_state_resuse___company_pastsign_jy' in tmp_target_table_rdd_columns_list:
            tmp_source_table_rdd = tmp_source_table_rdd.withColumnRenamed('avg_clue_state_refuse___company_pastsign_jy', 
                                                                          'AVG_clue_state_resuse___company_pastsign_jy')
            tmp_source_table_rdd = tmp_source_table_rdd.withColumnRenamed('max_clue_state_refuse___company_pastsign_jy', 
                                                                          'Max_clue_state_resuse___company_pastsign_jy')
            tmp_source_table_rdd = tmp_source_table_rdd.withColumnRenamed('min_clue_state_refuse___company_pastsign_jy', 
                                                                          'MIN_clue_state_resuse___company_pastsign_jy')
            
        tmp_source_table_rdd = tmp_source_table_rdd.select(tmp_target_table_rdd_columns_list)
        
        # 创建临时view
        tmp_source_table_rdd.createTempView("tmp_view_for_upload")

        # 上传特征（如果是第一次上传，则清空对应dt的数据）
        sql_str = """insert overwrite table """ + Target_Table_Name + """ 
                 partition(dt='""" + tmp_up_load_table_dt + """')(
                 select * from tmp_view_for_upload
                )    
                """

        Spark_Session.sql(sql_str)

        # 删除临时view
        Spark_Session.catalog.dropTempView("tmp_view_for_upload")
# Out:
# tmp.tmp___JL_MP_N_Feat___mobile_company_site___Company_Node_UID___Groupby_Result___04_18
# tmp.tmp___JingLian_Meta_Path_Feature___mobile_company_site___Company_Node_UID___Groupby_Result___04_18
# 2023-05-01
# tmp.tmp___JL_MP_N_Feat___mobile_company_site___Company_Node_UID___Groupby_Summary___04_18
# tmp.tmp___JingLian_Meta_Path_Feature___mobile_company_site___Company_Node_UID___Groupby_Result_Summary___04_18
# 2023-05-01
# tmp.tmp___JL_MP_N_Feat___company_related_to_industry___Industry_Type_Node_l4_UID___Groupby_Result___04_18
# tmp.tmp___JingLian_Meta_Path_Feature___company_related_to_industry___Industry_Type_Node_l4_UID___Groupby_Result___04_18
# 2023-05-01
# tmp.tmp___JL_MP_N_Feat___company_related_to_industry___Industry_Type_Node_l4_UID___Groupby_Summary___04_18
# tmp.tmp___JingLian_Meta_Path_Feature___company_related_to_industry___Industry_Type_Node_l4_UID___Groupby_Result_Summary___04_18
# 2023-05-01
# ...
